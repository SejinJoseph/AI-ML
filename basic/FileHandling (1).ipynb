# %%
# Import necessary modules
import os
import shutil
import glob

# %%
#Check current working directory
print("Current working directory")
current_dir = os.getcwd()
print(current_dir)

# %%
#List files and folders in current directory
print("\nList files and folders")
items = os.listdir('.')
print(items)
# Out:
# List files and folders
# ['.config', 'sample_data']

# %%
# Create some test files for demonstration
print("\n Create sample files")
test_files = ['doc1.txt', 'image1.jpg', 'data.csv']
for file in test_files:
    with open(file, 'w') as f:
        f.write("Sample content for " + file)
print(f"Created files: {test_files}")
# Out:
#  Create sample files
# Created files: ['doc1.txt', 'image1.jpg', 'data.csv']

# %%
#Check if a file exists and get its size
print("\nFile existence and size check")
file_to_check = 'doc1.txt'
exists = os.path.exists(file_to_check)
size = os.path.getsize(file_to_check) if exists else 0
print(f"Does {file_to_check} exist? {exists}")
print(f"Size of {file_to_check}: {size} bytes")
# Out:
# File existence and size check
# Does doc1.txt exist? True
# Size of doc1.txt: 27 bytes

# %%
#Create new directories for organizing files
print("\n Create directories 'images' and 'documents'")
os.makedirs('images', exist_ok=True)
os.makedirs('documents', exist_ok=True)
print("Directories created (if not existing).")
# Out:
#  Create directories 'images' and 'documents'
# Directories created (if not existing).

# %%
#Rename a single file using os.rename()
print("\nRename 'doc1.txt' to 'document_001.txt'")
os.rename('doc1.txt', 'document_001.txt')
print("Renamed file:")
print(os.listdir('.'))
# Out:
# Rename 'doc1.txt' to 'document_001.txt'
# Renamed file:
# ['.config', 'documents', 'image1.jpg', 'images', 'data.csv', 'document_001.txt', 'sample_data']

# %%
# Bulk rename all .txt files by adding 'file_' prefix
print("\nBulk rename .txt files with prefix 'file_'")
txt_files = [f for f in os.listdir('.') if f.endswith('.txt')]
for f in txt_files:
    new_name = 'file_' + f
    os.rename(f, new_name)
print("After bulk renaming:")
print(os.listdir('.'))
# Out:
# Bulk rename .txt files with prefix 'file_'
# After bulk renaming:
# ['.config', 'documents', 'file_document_001.txt', 'image1.jpg', 'images', 'data.csv', 'sample_data']

# %%
# Copy a file using shutil.copy()
print("\nCopy 'file_document_001.txt' to 'documents' folder")
# Note: Adjust for renamed file names dynamically
file_to_copy = [f for f in os.listdir('.') if 'document' in f or 'file_' in f and f.endswith('.txt')][0]
shutil.copy(file_to_copy, 'documents/')
print("Files in 'documents' folder:")
print(os.listdir('documents'))
# Out:
# Copy 'file_document_001.txt' to 'documents' folder
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# /tmp/ipykernel_3526/1069426737.py in <cell line: 0>()
#       3 # Note: Adjust for renamed file names dynamically
#       4 file_to_copy = [f for f in os.listdir('.') if 'document' in f or 'file_' in f and f.endswith('.txt')][0]
# ----> 5 shutil.copy(file_to_copy, 'documents/')
#       6 print("Files in 'documents' folder:")
#       7 print(os.listdir('documents'))
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
# ...

# %%
# Move and rename a file using shutil.move()
print("\nMove and rename 'image1.jpg' to 'images/photo_001.jpg'")
shutil.move('image1.jpg', 'images/photo_001.jpg')
print("Files in 'images' folder:")
print(os.listdir('images'))
# Out:
# Move and rename 'image1.jpg' to 'images/photo_001.jpg'
# Files in 'images' folder:
# ['photo_001.jpg']

# %%
#Copy an entire directory using shutil.copytree(
print("\nCopy 'images' folder to 'images_backup'")
shutil.copytree('images', 'images_backup', dirs_exist_ok=True)
print("Folders after backup:")
print(os.listdir('.'))
# Out:
# Copy 'images' folder to 'images_backup'
# Folders after backup:
# ['.config', 'documents', 'file_document_001.txt', 'images', 'data.csv', 'images_backup', 'sample_data']

# %%
#Organize files by extension into folders
print("\nOrganize files by extensions")
def organize_files():
    folders = {'jpg': 'images', 'txt': 'documents', 'csv': 'data'}
    for filename in os.listdir('.'):
        if os.path.isfile(filename):
            ext = filename.split('.')[-1].lower()
            if ext in folders:
                dest_folder = folders[ext]
                os.makedirs(dest_folder, exist_ok=True)
                shutil.move(filename, os.path.join(dest_folder, filename))
                print(f"Moved {filename} to {dest_folder}/")

organize_files()
print("Current directory structure:")
print(os.listdir('.'))
# Out:
# Organize files by extensions
# Moved file_document_001.txt to documents/
# Moved data.csv to data/
# Current directory structure:
# ['.config', 'documents', 'data', 'images', 'images_backup', 'sample_data']

# %%
# Delete a file safely
print("\nCreate and delete a temporary file safely")
temp_file = 'temp_test.txt'
with open(temp_file, 'w') as f:
    f.write("Temporary data")
print(f"Created {temp_file}")
if os.path.exists(temp_file):
    os.remove(temp_file)
    print(f"Deleted {temp_file}")
# Out:
# Create and delete a temporary file safely
# Created temp_test.txt
# Deleted temp_test.txt

# %%
# Delete a non-empty directory safely using shutil.rmtree()
print("\nCreate and delete 'test_delete' folder with content")
folder = 'test_delete'
os.makedirs(folder, exist_ok=True)
test_file_inside = os.path.join(folder, 'test.txt')
with open(test_file_inside, 'w') as f:
    f.write("File inside folder to be deleted")
print(f"Folder and file created: {folder}/{test_file_inside}")
# Deleting folder recursively
shutil.rmtree(folder)
print(f"Deleted folder '{folder}' and its contents")
# Out:
# Create and delete 'test_delete' folder with content
# Folder and file created: test_delete/test_delete/test.txt
# Deleted folder 'test_delete' and its contents

# %%
#Walk directory tree and print file structure
print("\nStep 15: Walk current directory tree")
for root, dirs, files in os.walk('.'):
    print(f"\nDirectory: {root}")
    print("Subdirectories:", dirs)
    print("Files:", files)
# Out:
# Step 15: Walk current directory tree
#
# Directory: .
# Subdirectories: ['.config', 'documents', 'data', 'images', 'images_backup', 'sample_data']
# Files: []
#
# Directory: ./.config
# Subdirectories: ['configurations', 'logs']
# Files: ['.last_opt_in_prompt.yaml', 'config_sentinel', 'default_configs.db', 'active_config', 'hidden_gcloud_config_universe_descriptor_data_cache_configs.db', 'gce', '.last_survey_prompt.yaml', '.last_update_check.json']
#
# Directory: ./.config/configurations
# Subdirectories: []
# Files: ['config_default']
#
# Directory: ./.config/logs
# Subdirectories: ['2026.03.23']
# Files: []
#
# Directory: ./.config/logs/2026.03.23
# Subdirectories: []
# Files: ['13.29.02.727930.log', '13.29.47.572748.log', '13.29.34.829749.log', '13.29.24.904753.log', '13.29.36.176357.log', '13.29.46.856905.log']
#
# Directory: ./documents
# Subdirectories: []
# Files: ['file_document_001.txt']
#
# Directory: ./data
# Subdirectories: []
# Files: ['data.csv']
#
# ...

# %%
# @title
# Step 16: Handling errors - safe file move with try-except
print("\nStep 16: Move file with error handling")
def safe_move(src, dest):
    try:
        if os.path.exists(src):
            shutil.move(src, dest)
            print(f"Moved '{src}' to '{dest}'")
        else:
            print(f"Source '{src}' not found.")
    except PermissionError:
        print("Permission denied.")
    except Exception as e:
        print(f"Error: {e}")
# Out:
# Step 16: Move file with error handling

# %%
# Attempt to move a file that may not exist
safe_move('non_existent_file.txt', 'documents/')
# Out:
# Source 'non_existent_file.txt' not found.

# %%
import csv

# %%
with open('file.csv') as csvfile:
    myreader = csv.reader(csvfile,delimiter=',')
    print("%10s"%"EMPNO", "%20s"%"EMP NAME", "%10s"%"SALARY")
    print("===============================================")
    for row in myreader:
        # Skip empty or short rows
        if len(row) < 3:
            continue
        print("%10s"%row[0],"%20s"%row [1], "%10s"%row [2])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3526/2916307275.py in <cell line: 0>()
# ----> 1 with open('file.csv') as csvfile:
#       2     myreader = csv.reader(csvfile,delimiter=',')
#       3     print("%10s"%"EMPNO", "%20s"%"EMP NAME", "%10s"%"SALARY")
#       4     print("===============================================")
#       5     for row in myreader:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file.csv'

# %%
#writing data
with open('file.csv',mode='a') as csvfile:
    mywriter = csv.writer(csvfile,delimiter=',')
    ans='y'
    while ans.lower()=='y':
        empno=int(input("Enter a EMPNO:"))
        empname=input("Enter a EMPName:")
        salary=int(input("Enter a Salary:"))
        mywriter.writerow([empno,empname,salary])
        print("Data Saved")
    ans=input("Add more ?")
# Out:
# Data Saved
# Data Saved
# Data Saved
# Data Saved

# %%
with open('file.csv') as csvfile:
    myreader = csv.reader(csvfile,delimiter=',')
    while  ans=='y':
        found= False
        e=int(input("Enter a EMPNO:"))
        for row in myreader:
            if len(row)!=0:
                if int(row[0])==e:
                        print("Name",row[1])
                        print("Salary",row[2])
                        found=True
                        break
        if not found:
            print("Employee not found")

        ans1=input("Search more?(Y)")

# %%
#Copying Files and Folders
import shutil

source = "Documents/file_final.txt"
destination = "Documents/file_paper.txt"

shutil.copy(source, destination)

print("File copied successfully!")

# %%
shutil.copytree("New folder", "Documents_backup")

print("Folder copied!")

# %%
path = 'E:/VETRI NICHAYAM'

statistics=shutil.disk_usage(path)

print(statistics)
# Out:
# usage(total=14733537280, used=4641267712, free=10092269568)

# %%
#ZIP File Creation
import shutil

shutil.make_archive("project_backup", "zip", "mini_erp_hr")

print("Archive created!")

# %%
import shutil, os
source_dir = "Documents"
target_dir = "Documents_backup"
os.makedirs(target_dir, exist_ok=True)
for filename in os.listdir(source_dir):
    if filename.endswith(".txt"):
        shutil.move(os.path.join(source_dir, filename), target_dir)
shutil.make_archive("target_archive", "zip", target_dir)
'target_archive.zip'
# Out:
# 'target_archive.zip'

# %% [markdown]
# Web Scraping in Python

# %%
# Import necessary Libraries
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "http://www.hubertiming.com/results/2017GPTR10K"
html = urlopen(url) #module is used to open the URL and retrieve its content.

# %%
print(url)
# Out:
# http://www.hubertiming.com/results/2017GPTR10K

# %%
#To extract the HTML from the page, first use the HTTPResponse object’s .read() method, which returns a sequence of bytes.
#Then use .decode() to decode the bytes to a string using UTF-8:
html_bytes = html.read()
html = html_bytes.decode("utf-8")

# %%
print(html)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#
#
#
#
#
#
#     <meta property="og:title" content="Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!" />
#     <meta property="og:description" content="Results of the 2017 Intel Great Place to Run \ Urban Clash Games at Hillsboro Stadium in Hillsboro, OR" />
#     <meta property="og:image" content="https://www.hubertiming.com/results/2017GPTRForResults.jpg" />
#
#     <meta property="og:url" content="https://www.hubertiming.com/results/2017GPTR10K" />
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#
#     <title>Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!</title>
#
#     <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/css/bootstrap.min.css" crossorigin="anonymous">
#
#     <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.13.0/css/all.css">
# ...

# %%
pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 2.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/4.0 MB 2.4 MB/s eta 0:00:02
#    --------------- ------------------------ 1.6/4.0 MB 2.0 MB/s eta 0:00:02
#    --------------- ------------------------ 1.6/4.0 MB 2.0 MB/s eta 0:00:02
#    ------------------ --------------------- 1.8/4.0 MB 1.5 MB/s eta 0:00:02
#    -------------------- ------------------- 2.1/4.0 MB 1.5 MB/s eta 0:00:02
#    -------------------------- ------------- 2.6/4.0 MB 1.6 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 1.8 MB/s  0:00:02
# ...

# %%
#BeautifulSoup is a popular library used for web scraping and parsing HTML and XML documents.
#By importing this class, the user can create an instance of BeautifulSoup and use its methods to extract data from web pages.
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
#Tag object
tag = soup.html
print (type(tag))
print(tag.name)
# Out:
# <class 'bs4.element.Tag'>
# html

# %%
#changing the name of the tag
tag=soup.b
print(tag.name)
tag.name="Strong"
print(tag)
# Out:
# b
# <Strong>10K:</Strong>

# %%
#NavigableString Object
soup = BeautifulSoup("<h2 id='message'>Hello, Everyone!</h2>", 'html.parser')
print(soup.string)

print(type(soup.string))
# Out:
# Hello, Everyone!
# <class 'bs4.element.NavigableString'>

# %%
#Comment Object
markup = "<b><!--This is a comment text in HTML--></b>"
soup = BeautifulSoup(markup, 'html.parser')
comment = soup.b.string
print (comment, type(comment))
# Out:
# This is a comment text in HTML <class 'bs4.element.Comment'>

# %%
# Get the title
title = soup.title
print(title)
# Out:
# None

# %%
#Get the title content
text = soup.text
print(text)

# %%
pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 1.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/9.7 MB 1.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.7 MB 1.9 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.7 MB 2.0 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.7 MB 2.0 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.7 MB 1.4 MB/s eta 0:00:06
#    --------- ------------------------------ 2.4/9.7 MB 1.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.6/9.7 MB 1.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.9/9.7 MB 1.4 MB/s eta 0:00:05
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

url = "https://medium.com/@armaansinghbhau8/automate-backups-with-python-a-simple-guide-to-safeguarding-your-data-bbb241dcdb42"

#setup webdriver
driver = webdriver.Chrome()

#Navigate to a Web Page:
driver.get(url)

time.sleep(5)  # allow JS to load fully

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

print(soup.title.text)
driver.quit()

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://quotes.toscrape.com/"

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

quotes_list = []

for quote in soup.find_all("div", class_="quote"):
    text = quote.find("span", class_="text").text
    author = quote.find("small", class_="author").text
    quotes_list.append([text, author])

with open("quotes1.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Quote", "Author"])
    writer.writerows(quotes_list)

print("Scraped data stored successfully!")
# Out:
# Scraped data stored successfully!

# %%
#Collecting Images from a Webpage
import requests
from bs4 import BeautifulSoup

url = "https://codewolfy.com/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

#find only img
images = soup.find_all("img")

for image in images:
    if image.has_attr("src"):
        print(image["src"])
# Out:
# https://codewolfy.com/wp-content/uploads/codewolfy-logo-new.png
# https://codewolfy.com/wp-content/uploads/Access-Environment-Variables-in-Python-768x403.webp
# https://codewolfy.com/wp-content/uploads/Python-FastAPI-Tutorial-768x403.webp
# https://codewolfy.com/wp-content/uploads/Validate-API-Requests-in-Node.js-Express-Using-Joi-768x403.webp
# https://codewolfy.com/wp-content/uploads/How-to-Use-Winston-for-Logging-in-Node.js-768x403.webp
# https://codewolfy.com/wp-content/uploads/Building-Reliable-Queues-in-Node.js-with-Redis-and-BullMQ-768x403.webp
# https://codewolfy.com/wp-content/uploads/Build-a-Custom-API-Rate-Limiter-in-Node.js-From-Scratch-768x403.webp
# https://codewolfy.com/wp-content/uploads/Implement-Rate-Limiting-in-Node.js-with-Express-Rate-Limit-768x403.webp
# https://codewolfy.com/wp-content/uploads/How-to-Implement-JWT-Authentication-in-Node.js-768x403.webp
# https://codewolfy.com/wp-content/uploads/How-to-Create-Dynamic-Sitemaps-in-React-Applications-768x403.webp
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as ec
from selenium.webdriver.support.ui import WebDriverWait

# %%
#Launching the browser
driver = webdriver.Chrome()
driver.get('https://practicesoftwaretesting.com/')

# %%
#switching to headless browser
options = webdriver.ChromeOptions()
options.add_argument('--headless=new')
driver = webdriver.Chrome(options=options)
driver.get('https://practicesoftwaretesting.com/')

# %%
#select multiple elements
nav_items = driver.find_elements(By.CLASS_NAME, 'nav-item')
nav_items_names = [nav_item.text for nav_item in nav_items]
print(nav_items_names)

# Output:
# ['Home', 'Categories', 'Contact', 'Sign in']
# Out:
# ['', '', '', '']

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL we want to scrape
url = 'https://books.toscrape.com/'

# Pretend to be a real browser (This is the Best Practice)
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# %%
from bs4 import BeautifulSoup
response = requests.get(url, headers = headers)

# Checks if the request was a success (Status code == 200)

if response.status_code == 200:
    print("We are Connected")
    soup = BeautifulSoup(response.content, 'html.parser')
else:
    print('Failed to Connect and retrive page')
# Out:
# We are Connected

# %%
# Find all book containers
books = soup.find_all('article', class_='product_pod')

book_data = []

for books in books:
    #Extract the title (It's inside an 'a' tag within 'h3')
    title = books.h3.a['title']

    #Extract the Price
    Price = books.find('p', class_='price_color').text

    #Store the extracted title and price
    book_data.append({
        'Book Title': title,
        'Price': Price
    })

print(f"Scraped {len(book_data)} books")
# Out:
# Scraped 20 books

# %%
df = pd.DataFrame(book_data)

# Clean the data: Remove the Currency '£' symbol
df['Price'] = df['Price'].str.replace('£', '')

# Save to CSV
df.to_csv('book_dataset.csv', index=False)
print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv("book_dataset.csv")

# %%
print(df)
# Out:
#                                            Book Title  Price
# 0                                A Light in the Attic  51.77
# 1                                  Tipping the Velvet  53.74
# 2                                          Soumission  50.10
# 3                                       Sharp Objects  47.82
# 4               Sapiens: A Brief History of Humankind  54.23
# 5                                     The Requiem Red  22.65
# 6   The Dirty Little Secrets of Getting Your Dream...  33.34
# 7   The Coming Woman: A Novel Based on the Life of...  17.93
# 8   The Boys in the Boat: Nine Americans and Their...  22.60
# 9                                     The Black Maria  52.15
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  13.99
# 11                              Shakespeare's Sonnets  20.66
# 12                                        Set Me Free  17.46
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  52.29
# ...

# %%
# Convert Price column to float
df['Price'] = df['Price'].astype(float)

# %%
print(df.head())
# Out:
#                               Book Title  Price
# 0                   A Light in the Attic  51.77
# 1                     Tipping the Velvet  53.74
# 2                             Soumission  50.10
# 3                          Sharp Objects  47.82
# 4  Sapiens: A Brief History of Humankind  54.23

# %%
#Check Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Book Title  20 non-null     object
#  1   Price       20 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 452.0+ bytes

# %%
print(df.describe())
# Out:
#            Price
# count  20.000000
# mean   38.048500
# std    15.135231
# min    13.990000
# 25%    22.637500
# 50%    41.380000
# 75%    51.865000
# max    57.250000

# %%
top_expensive = df.sort_values(by='Price', ascending=False).head(5)
print(top_expensive)
# Out:
#                                            Book Title  Price
# 15  Our Band Could Be Your Life: Scenes from the A...  57.25
# 4               Sapiens: A Brief History of Humankind  54.23
# 1                                  Tipping the Velvet  53.74
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  52.29
# 9                                     The Black Maria  52.15

# %%
avg_price = df['Price'].mean()
print("Average Book Price:", avg_price)
# Out:
# Average Book Price: 38.048500000000004

# %%
plt.figure()
plt.hist(df['Price'], bins=10)
plt.xlabel("Book Price")
plt.ylabel("Number of Books")
plt.title("Book Price Distribution")
plt.show()

# %%
plt.figure()
plt.plot(df['Price'])
plt.axhline(avg_price)
plt.xlabel("Book Index")
plt.ylabel("Price")
plt.title("Book Prices with Average Line")
plt.show()

# %%
pip install python-pptx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 23.7 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 23.0 kB/s eta 0:00:00
# ...

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.enum.text import PP_ALIGN
from pptx.dml.color import RGBColor

def create_unsupervised_learning_ppt():
    # Create presentation
    prs = Presentation()

    # Slide 1: Title Slide
    slide_layout = prs.slide_layouts[0]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    subtitle = slide.placeholders[1]
    title.text = "🎓 Unsupervised Machine Learning"
    subtitle.text = "A Beginner's Guide for First-Year Students\n\nPresented by: [Your Name]"

    # Slide 2: What is Unsupervised Learning?
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = "🤔 What is Unsupervised Learning?"
    content.text = """
    Definition:
    • Machine learning WITHOUT labeled data
    • Computer finds patterns on its own
    • No teacher to guide the answers

    Real-World Analogy:
    🎵 Spotify creating playlists automatically
    🛒 Amazon's "Customers also bought..."
    📧 Email spam detection

    Key Idea: Finding hidden structures in data!
    """

    # Slide 3: Supervised vs Unsupervised
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = "🆚 Supervised vs Unsupervised Learning"
    content.text = """
    SUPERVISED LEARNING:
    ✅ Has labeled data
    ✅ Knows the correct answers
    ✅ Like learning with a teacher
    Example: Spam detection, Price prediction

    UNSUPERVISED LEARNING:
    ❌ No labeled data
    ✅ Finds hidden patterns
    ✅ Self-learning
    Example: Customer segmentation, Grouping similar items
    """

    # Slide 4: Types of Unsupervised Learning
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = "🎯 Types of Unsupervised Learning"
    content.text = """
    1. CLUSTERING 👥
       • Grouping similar data points
       • Example: Customer segmentation

    2. DIMENSIONALITY REDUCTION 📉
       • Reducing features while keeping info
       • Example: PCA (Principal Component Analysis)

    3. ASSOCIATION 🔗
       • Finding relationships between variables
       • Example: Market basket analysis
    """

    # Slide 5: K-Means Clustering
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = "🔷 K-Means Clustering Algorithm"
    content.text = """
    How it Works:
    1. Choose K (number of clusters)
    2. Randomly place K cluster centers
    3. Assign each point to nearest center
    4. Move centers to average position
    5. Repeat steps 3-4 until stable

    Advantages:
    ⚡ Fast and simple
    📊 Works well with large datasets
    🎯 Easy to implement

    Use Cases:
    • Customer segmentation
    • Image compression
    • Document clustering
    """

    # Slide 6: K-Means Code Example
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = "💻 K-Means Code Example"
    content.text = """
    from sklearn.cluster import KMeans
    import numpy as np

    # Sample data
    X = np.array([[1, 2], [1, 4], [1, 0],
                  [4, 2], [4, 4], [4, 0]])

    # Create and train model
    kmeans = KMeans(n_clusters=2, random_state=0)
    kmeans.fit(X)

    # Get results
    labels = kmeans.labels_
    centers = kmeans.cluster_centers_

    print("Clusters:", labels)
    print("Centers:", centers)
    """

    # Slide 7: Hierarchical Clustering
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = "🌳 Hierarchical Clustering"
    content.text = """
    Concept:
    • Creates a tree-like structure (dendrogram)
    • No need to specify number of clusters
    • Two approaches:
      - Agglomerative (bottom-up)
      - Divisive (top-down)

    Advantages:
    📊 Visual representation (dendrogram)
    🎯 No need to pre-define K
    🔍 Shows relationships between clusters

    Disadvantages:
    ️ Slower for large datasets
    💾 Requires more memory
    """

    # Slide 8: PCA - Dimensionality Reduction
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = "📉 PCA (Principal Component Analysis)"
    content.text = """
    What is PCA?
    • Reduces number of features
    • Keeps most important information
    • Transforms data to new coordinate system

    Why Use PCA?
    🎨 Visualize high-dimensional data
    ⚡ Speed up machine learning algorithms
    🗜️ Reduce storage requirements
    🔇 Remove noise

    How it Works:
    1. Find directions of maximum variance
    2. Project data onto these directions
    3. Keep top K principal components
    """

    # Slide 9: PCA Code Example
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = "💻 PCA Code Example"
    content.text = """
    from sklearn.decomposition import PCA
    from sklearn.datasets import load_iris

    # Load data
    iris = load_iris()
    X = iris.data  # 4 features

    # Apply PCA
    pca = PCA(n_components=2)  # Reduce to 2D
    X_pca = pca.fit_transform(X)

    print("Original shape:", X.shape)
    print("Reduced shape:", X_pca.shape)
    print("Variance explained:",
          pca.explained_variance_ratio_)
    """

    # Slide 10: Real-World Application
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = "🛍️ Real-World: Mall Customer Segmentation"
    content.text = """
    Business Problem:
    Segment customers for targeted marketing

    Features:
    • Annual Income (k$)
    • Spending Score (1-100)

    Customer Segments Found:
    1. High Income, Low Spending → Careful shoppers
    2. High Income, High Spending → Target customers!
    3. Low Income, High Spending → Impulse buyers
    4. Low Income, Low Spending → Budget conscious
    5. Medium Income, Medium → Average customers

    Business Impact: Better marketing strategies!
    """

    # Slide 11: Algorithm Comparison
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = "📊 Algorithm Comparison"
    content.text = """
    ┌─────────────┬─────────┬──────────┬──────────┐
    │  Algorithm  │  Speed  │ Accuracy │ Best For │
    ├─────────────┼───────────────────┼──────────
    │  K-Means    │   Fast  │  Medium  │  Large   │
    │             │         │          │  data    │
    ├─────────────┼─────────┼──────────┼──────────┤
    │Hierarchical │  Slow   │   High   │  Small   │
    │             │         │          │  data    │
    ├─────────────┼─────────┼──────────┼──────────┤
    │    PCA      │  Medium │   High   │  Visual  │
    │             │         │          │  & Reduc │
    └─────────────┴─────────┴──────────┴──────────┘
    """

    # Slide 12: Key Takeaways
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = "🌟 Key Takeaways"
    content.text = """
    ✅ Unsupervised Learning finds hidden patterns without labels

    ✅ K-Means: Fast, simple, most popular clustering

    ✅ Hierarchical: Creates tree structure, no need for K

    ✅ PCA: Reduces dimensions while keeping important info

    ✅ Elbow Method: Helps find optimal number of clusters

    ✅ Real applications: Customer segmentation,
       recommendation systems, image compression

    🎯 Practice is key to mastering ML!
    """

    # Slide 13: Practice Exercises
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = " Practice Exercises"
    content.text = """
    Exercise 1: Student Clustering
    Cluster students based on:
    - Study hours per week
    - Grades

    Exercise 2: Iris Dataset
    Use PCA to reduce 4D iris data to 2D
    Visualize the clusters

    Exercise 3: Mall Customers
    - Load customer data
    - Apply K-Means with different K values
    - Use Elbow method to find optimal K

    Resources:
    • Kaggle.com - Free datasets
    • Scikit-learn documentation
    • Google Colab - Free GPU
    """

    # Slide 14: Next Steps
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = "🚀 Your Learning Path"
    content.text = """
    Week 1-2:
    ✓ Install Python & libraries
    ✓ Practice K-Means on simple data
    ✓ Understand clustering concepts

    Week 3-4:
    ✓ Learn Hierarchical clustering
    ✓ Study PCA and dimensionality reduction
    ✓ Work on Kaggle datasets

    Week 5-6:
    ✓ Complete a mini-project
    ✓ Participate in Kaggle competition
    ✓ Read research papers

    Tools to Install:
    pip install scikit-learn pandas numpy matplotlib jupyter
    """

    # Slide 15: Q&A / Thank You
    slide_layout = prs.slide_layouts[0]
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    subtitle = slide.placeholders[1]
    title.text = "❓ Questions & Discussion"
    subtitle.text = """
    Thank You for Your Attention!

    📧 Contact: [your.email@example.com]
    💻 GitHub: [your-github-profile]
    📚 Resources: github.com/awesome-ml-resources

    "Machine learning is like learning to ride a bike.
    You'll fall a few times, but keep practicing!"

    Happy Learning! 🎉✨
    """

    # Save presentation
    prs.save('Unsupervised_Machine_Learning_Presentation.pptx')
    print("✅ Presentation saved successfully!")
    print("📁 File: Unsupervised_Machine_Learning_Presentation.pptx")

# Run the function
if __name__ == "__main__":
    create_unsupervised_learning_ppt()
# Out:
# ✅ Presentation saved successfully!
# 📁 File: Unsupervised_Machine_Learning_Presentation.pptx
